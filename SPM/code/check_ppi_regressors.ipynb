# %%
from scipy import io
import matplotlib.pyplot as plt

# %%
tmp = io.loadmat('/data/ds-mlearn/derivatives/nipype/model2/1stLevel/sub-01/SPM.mat', simplify_cells=True)['SPM']



tmp.keys()
# Out:
# dict_keys(['xY', 'xBF', 'nscan', 'Sess', 'factor', 'xGX', 'xM', 'xX', 'xVi', 'SPMid', 'xsDes', 'swd', 'xVol', 'Vbeta', 'VResMS', 'VM', 'xCon'])

# %%
tmp['xX']['X'].shape
# Out:
# (1332, 210)

# %%
tmp['Sess'][0]['U'][0]['P']
# Out:
# [{'name': 'surprise',
#   'P': array([-1.52111623e-01,  1.43366548e-01,  4.10659066e-01,  6.54678017e-01,
#           8.79153692e-01,  1.08698570e+00,  1.28047268e+00,  1.46146766e+00,
#           1.63148630e+00, -1.52111623e-01, -4.82869520e-04,  1.43366548e-01,
#          -8.56910067e-01,  4.10659066e-01,  5.35321758e-01, -4.82428115e-01,
#           7.69161210e-01, -1.06474208e+00, -1.52111623e-01, -5.01204271e-02,
#           4.82913823e-02,  1.43366548e-01, -5.71465713e-01, -4.82428115e-01,
#          -1.02192524e+00, -3.12409467e-01, -2.31115405e-01, -7.77906285e-01,
#          -1.21237873e+00,  1.94341290e+00,  2.01625982e+00,  2.08726232e+00,
#          -9.24490417e-01, -3.45598598e-01, -2.79608523e-01, -1.15875475e+00,
#          -1.52111623e-01, -1.03409206e+00, -5.41471323e-01,  6.54678017e-01,
#          -8.56910067e-01, -1.17473456e+00, -1.11919911e+00,  2.53359029e-01,
#          -1.34163888e+00, -1.52111623e-01,  1.84324337e+00, -1.48270473e+00,
# ...

# %%
tmp['xSPM']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[70], line 1
# ----> 1 tmp['xSPM']
#
# KeyError: 'xSPM'

# %%
plt.imshow(tmp['xX']['X'])

# %%
plt.imshow(tmp['xX']['X']

# %%
plt.imshow(tmp['xX']['K'][1]['X'], aspect='auto', cmap='gray')
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[66], line 1
# ----> 1 plt.imshow(tmp['xX']['K'][1]['X'], aspect='auto', cmap='gray')
#
# KeyError: 'X'

# %%
tmp['xX']['name']
# Out:
# array(['Sn(1) ChoiceTactile*bf(1)',
#        'Sn(1) ChoiceTactilexsurprise^1*bf(1)',
#        'Sn(1) ChoiceTactilexV^1*bf(1)', 'Sn(1) FeedbackTactile*bf(1)',
#        'Sn(1) FeedbackTactilexrpe^1*bf(1)', 'Sn(1) trans_x',
#        'Sn(1) trans_y', 'Sn(1) trans_z', 'Sn(1) rot_x', 'Sn(1) rot_y',
#        'Sn(1) rot_z', 'Sn(1) a_comp_cor_00', 'Sn(1) a_comp_cor_01',
#        'Sn(1) a_comp_cor_02', 'Sn(1) a_comp_cor_03',
#        'Sn(1) a_comp_cor_04', 'Sn(1) RETROICOR (cardiac)',
#        'Sn(1) RETROICOR (cardiac)', 'Sn(1) RETROICOR (cardiac)',
#        'Sn(1) RETROICOR (cardiac)', 'Sn(1) RETROICOR (cardiac)',
#        'Sn(1) RETROICOR (cardiac)', 'Sn(1) RETROICOR (respiratory)',
#        'Sn(1) RETROICOR (respiratory)', 'Sn(1) RETROICOR (respiratory)',
#        'Sn(1) RETROICOR (respiratory)', 'Sn(1) RETROICOR (respiratory)',
#        'Sn(1) RETROICOR (respiratory)', 'Sn(1) RETROICOR (respiratory)',
#        'Sn(1) RETROICOR (respiratory)',
#        'Sn(1) RETROICOR (multiplicative)',
# ...

# %%
plt.plot(io.loadmat('/data/ds-mlearn/derivatives/nipype/model2/1stLevel/sub-01/PPI_cluster_0_con1_4_0_neg_3.mat', squeeze_me=True, simplify_cells=True)['PPI']['Y'])
plt.plot(io.loadmat('/data/ds-mlearn/derivatives/nipype/model2/1stLevel/sub-01/PPI_cluster_0_con1_4_0_neg_4.mat', squeeze_me=True, simplify_cells=True)['PPI']['Y'])

# %%
io.loadmat('/data/ds-mlearn/derivatives/nipype/model2/1stLevel/sub-01/PPI_cluster_0_con1_4_0_neg_3.mat', squeeze_me=True, simplify_cells=True)['PPI']
# Out:
# {'name': 'cluster_0_con1_4_0_neg_3',
#  'xY': {'name': 'cluster_0_con1_4_0_neg',
#   'Ic': nan,
#   'Sess': 3,
#   'xyz': array([41.18421053, 47.5       ,  3.84210526]),
#   'def': 'mask',
#   'spec': {'fname': '/shares/zne.uzh/multlearn/nipype/model2/1stLevel/sub-01/VOI_cluster_0_con1_4_0_neg_mask.nii',
#    'dim': array([65, 77, 56], dtype=uint8),
#    'dt': array([2, 0], dtype=uint8),
#    'mat': array([[   3. ,    0. ,    0. ,  -99.5],
#           [   0. ,    3. ,    0. , -135.5],
#           [   0. ,    0. ,    3.5,  -82. ],
#           [   0. ,    0. ,    0. ,    1. ]]),
#    'pinfo': array([  1,   0, 352], dtype=uint16),
#    'descrip': 'VOI',
#    'n': array([1, 1], dtype=uint8),
#    'private': {'hdr': {'sizeof_hdr': 348,
#      'data_type': '',
#      'db_name': '',
#      'extents': 0,
#      'session_error': 0,
#      'regular': 'r',
#      'dim_info': 0,
#      'dim': array([ 3, 65, 77, 56,  1,  1,  1,  1], dtype=int16),
#      'intent_p1': 0.0,
#      'intent_p2': 0.0,
# ...

# %%
y1 = io.loadmat('/data/ds-mlearn/derivatives/nipype/model2/1stLevel/sub-01/PPI_cluster_0_con1_4_0_neg_3.mat', squeeze_me=True, simplify_cells=True)['PPI']['Y']
y2 = io.loadmat('/data/ds-mlearn/derivatives/nipype/model2/1stLevel/sub-01/PPI_cluster_0_con1_4_0_neg_4.mat', squeeze_me=True, simplify_cells=True)['PPI']['Y']
r1 = io.loadmat('/data/ds-mlearn/derivatives/nipype/model2/1stLevel/sub-01/PPI_cluster_0_con1_4_0_neg_1.mat', squeeze_me=True, simplify_cells=True)['PPI']['ppi']
r2 = io.loadmat('/data/ds-mlearn/derivatives/nipype/model2/1stLevel/sub-01/PPI_cluster_0_con1_4_0_neg_2.mat', squeeze_me=True, simplify_cells=True)['PPI']['ppi']

# %%
plt.scatter(r1/y1, r2/y2, alpha=0.5)
plt.xlim(-1, 1)
plt.ylim(-1, 1)
# Out:
# (-1.0, 1.0)

# %%
plt.plot(r1)
plt.plot(r2)

# %%
# ppi1 = io.loadmat('/data/ds-mlearn/derivatives/nipype/model2/1stLevel/sub-01/PPI_cluster_0_con1_4_0_neg_1.mat', squeeze_me=True, simplify_cells=True)
# ppi2 = io.loadmat('/data/ds-mlearn/derivatives/nipype/model2/1stLevel/sub-01/PPI_cluster_0_con1_4_0_neg_2.mat', squeeze_me=True, simplify_cells=True)
ppi3 = io.loadmat('/data/ds-mlearn/derivatives/nipype/model2/1stLevel/sub-01/PPI_cluster_0_con5_3_1_pos_1.mat', squeeze_me=True, simplify_cells=True)
ppi3_ = io.loadmat('/data/ds-mlearn/derivatives/nipype/model2/1stLevel/sub-01/PPI_cluster_0_con5_3_1_pos_2.mat', squeeze_me=True, simplify_cells=True)
# plt.plot(ppi1['PPI']['P'])
# plt.plot(ppi2['PPI']['P'])
plt.plot(ppi3['PPI']['P'])
# plt.plot(ppi3_['PPI']['P'])
# plt.plot(ppi3['PPI']['ppi'])
# # plt.plot(ppi3['PPI']['Y'])
# plt.plot(ppi3['PPI']['Y'] * ppi3['PPI']['P'])


# plt.figure()
# plt.scatter(ppi3['PPI']['ppi'], ppi3['PPI']['Y']* ppi3['PPI']['P'], alpha=0.5)
# # plt.plot(ppi3_['PPI']['P'])

# %%
plt.plot(x['PPI']['ppi'])

# %%
u = io.loadmat('/data/ds-mlearn/derivatives/nipype/model2/1stLevel/sub-01/PPI_cluster_0_con1_4_0_neg_3.mat', squeeze_me=True, simplify_cells=True)['PPI']['psy']['u']

# %%
import numpy as np

np.asarray(u)
# Out:
# array(<8880x5 sparse matrix of type '<class 'numpy.float64'>'
# 	with 19022 stored elements in Compressed Sparse Column format>,
#       dtype=object)
