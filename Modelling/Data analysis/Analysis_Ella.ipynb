# %%
from random import *
import os
import glob
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import scipy.stats
import pandas as pd
import numpy.ma as ma
import pickle
import seaborn as sns

# %%
data = pd.read_csv('../../Data/Pilots/Ella/participant1.000000_savedValues.csv')

# %%
data.columns
# Out:
# Index(['trialNumber', 'runNumber', 'visualSet', 'audioPair_1', 'audioPair_2',
#        'audioPair_3', 'tactilePair_1', 'tactilePair_2', 'tactilePair_3',
#        'visual', 'audio', 'tactile', 'combinationConditionalProbability',
#        'correctResponse', 'chosenKey', 'accurate', 'reward', 'startTime',
#        'stimulusOnsetTime', 'stimulusOffsetTime', 'responsePressTime',
#        'responseTime', 'feedbackOnsetTime', 'feedbackOffsetTime',
#        'responseTimeThreshold', 'totalAccuracy', 'totalErrorRate',
#        'accurateIndex', 'inaccurateIndex'],
#       dtype='object')

# %%
data[:10]
# Out:
#    trialNumber  runNumber  visualSet  audioPair_1  audioPair_2  audioPair_3  \
# 0            1          1          0            2            1            0
# 1            2          1          0            2            1            0
# 2            3          1          0            2            1            0
# 3            4          1          0            2            1            0
# 4            5          1          0            2            1            0
# 5            6          1          0            2            1            0
# 6            7          1          0            2            1            0
# 7            8          1          0            2            1            0
# 8            9          1          0            2            1            0
# 9           10          1          0            2            1            0
#
#    tactilePair_1  tactilePair_2  tactilePair_3  visual  ...  \
# 0              2              0              1       1  ...
# 1              2              0              1       1  ...
# 2              2              0              1       0  ...
# 3              2              0              1       2  ...
# 4              2              0              1       1  ...
# 5              2              0              1       0  ...
# 6              2              0              1       0  ...
# 7              2              0              1       1  ...
# 8              2              0              1       0  ...
# 9              2              0              1       1  ...
#
#    stimulusOffsetTime  responsePressTime  responseTime feedbackOnsetTime  \
# 0            4.866745           4.865982      2.166903          6.394571
# 1            9.883486           9.882880      1.700212         11.401656
# 2           15.083807          15.083136      1.949706         16.601461
# 3           20.200557          20.199965      1.850205         21.718606
# 4           25.484398          25.483538      2.050156         27.009905
# 5           31.534441          31.533834      2.800304         33.050895
# 6           37.101243          37.100748      2.350095         38.617938
# 7           42.068085          42.067611      1.733532         43.584768
# 8           47.885058          47.884573      2.600226         49.401742
# 9           53.001865          53.001350      1.900124         54.518533
#
#   feedbackOffsetTime  responseTimeThreshold  totalAccuracy  totalErrorRate  \
# 0           7.433140                      3       1.000000        0.000000
# 1          12.433146                      3       0.500000        0.500000
# 2          17.633921                      3       0.666667        0.333333
# 3          22.750424                      3       0.750000        0.250000
# 4          28.051031                      3       0.800000        0.200000
# 5          34.084538                      3       0.666667        0.333333
# 6          39.651220                      3       0.714286        0.285714
# 7          44.618473                      3       0.750000        0.250000
# 8          50.436305                      3       0.666667        0.333333
# 9          55.551843                      3       0.600000        0.400000
#
#    accurateIndex  inaccurateIndex
# 0              1                1
# 1              2                1
# 2              2                2
# 3              3                2
# 4              4                2
# 5              5                2
# 6              5                3
# 7              6                3
# 8              7                3
# 9              7                4
#
# [10 rows x 29 columns]

# %%
data_block1 = data[data.runNumber == 1]
data_block2 = data[data.runNumber == 2]
data_block3 = data[data.runNumber == 3]

# %%
# Out:
# (0, 29)
