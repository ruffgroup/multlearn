# %%
from random import *
import os
import glob
import numpy as np
import matplotlib.pyplot as plt
import scipy.stats
import pandas as pd
import numpy.ma as ma
import pickle
import seaborn as sns
import sys

# %%
data = pd.read_csv('../../Data/Pilots/Ella/participant1.000000_savedValues.csv')

# %%
info = pd.read_csv('../../Data/Pilots/Ella/participant1.000000_expInfo.csv')

# %%
data.columns
# Out:
# Index(['trialNumber', 'runNumber', 'visualSet', 'audioPair_1', 'audioPair_2',
#        'audioPair_3', 'tactilePair_1', 'tactilePair_2', 'tactilePair_3',
#        'visual', 'audio', 'tactile', 'combinationConditionalProbability',
#        'correctResponse', 'chosenKey', 'accurate', 'reward', 'startTime',
#        'stimulusOnsetTime', 'stimulusOffsetTime', 'responsePressTime',
#        'responseTime', 'feedbackOnsetTime', 'feedbackOffsetTime',
#        'responseTimeThreshold', 'totalAccuracy', 'totalErrorRate',
#        'accurateIndex', 'inaccurateIndex'],
#       dtype='object')

# %%
info.columns
# Out:
# Index(['title', 'experimenter', 'participantID', 'participantAge', 'date',
#        'expToolbox', 'nrRuns', 'nrTrials', 'audioPair_1', 'audioPair_2',
#        'audioPair_3', 'A', 'B', 'C', 'modality0AFrequency',
#        'modality0BFrequency', 'modality0CFrequency', 'modality1AFrequency',
#        'modality1BFrequency', 'modality1CFrequency', 'modality2AFrequency',
#        'modality2BFrequency', 'modality2CFrequency', 'interRunBreak',
#        'responseTimeThreshold', 'viewParam', 'tactilePair_1', 'tactilePair_2',
#        'tactilePair_3', 'Aaudio', 'Baudio', 'Caudio', 'Atactile', 'Btactile',
#        'Ctactile', 'rewardMagnitude', 'rewardProbability',
#        'audioGreenPairs_1_1', 'audioGreenPairs_1_2', 'audioGreenPairs_2_1',
#        'audioGreenPairs_2_2', 'audioGreenPairs_3_1', 'audioGreenPairs_3_2',
#        'tactileGreenPairs_1_1', 'tactileGreenPairs_1_2',
#        'tactileGreenPairs_2_1', 'tactileGreenPairs_2_2',
# ...

# %%
info.audioGreenPairs_1_2
# Out:
# 0    2
# Name: audioGreenPairs_1_2, dtype: int64

# %%
data_block4.audioPair_1
# Out:
# 180    2
# 181    2
# 182    2
# 183    2
# 184    2
# 185    2
# 186    2
# 187    2
# 188    2
# 189    2
# 190    2
# 191    2
# 192    2
# 193    2
# 194    2
# 195    2
# 196    2
# 197    2
# 198    2
# 199    2
# 200    2
# 201    2
# 202    2
# 203    2
# 204    2
# 205    2
# 206    2
# 207    2
# 208    2
# 209    2
# 210    2
# 211    2
# 212    2
# 213    2
# 214    2
# 215    2
# 216    2
# 217    2
# 218    2
# 219    2
# 220    2
# 221    2
# 222    2
# 223    2
# 224    2
# 225    2
# 226    2
# 227    2
# 228    2
# 229    2
# 230    2
# 231    2
# 232    2
# 233    2
# 234    2
# 235    2
# 236    2
# 237    2
# 238    2
# 239    2
# Name: audioPair_1, dtype: int64

# %% [markdown]
# # data[:10]

# %%
data_block1 = data[data.runNumber == 1]
data_block2 = data[data.runNumber == 2]
data_block3 = data[data.runNumber == 3]
data_block4 = data[data.runNumber == 4]

# %%
plt.plot(list(range(1,20)), data_block1.totalAccuracy[1:20], 'g')
plt.plot(list(range(21,40)), data_block1.totalAccuracy[41:60], 'g')
plt.plot(list(range(41,60)), data_block2.totalAccuracy[21:40], 'r')
plt.title("Tactile-Visual accuracy")
plt.xlabel('round number')
plt.ylabel('accuracy')
# Out:
# Text(0, 0.5, 'accuracy')

# %%
plt.plot(list(range(1,20)), data_block1.totalAccuracy[21:40], 'g')
plt.plot(list(range(22,40)), data_block2.totalAccuracy[2:20], 'r')
plt.plot(list(range(41,60)), data_block2.totalAccuracy[41:60], 'r')
plt.title("Audio-Visual accuracy")
plt.xlabel('round number')
plt.ylabel('accuracy')
# Out:
# Text(0, 0.5, 'accuracy')

# %%
plt.plot(data_block3.totalAccuracy[3:60])
plt.title("Audio-Visual accuracy (same block)")
plt.xlabel('round number')
plt.ylabel('accuracy')
# Out:
# Text(0, 0.5, 'accuracy')

# %%
plt.plot(data_block4.totalAccuracy[3:60])
plt.title("Tactile-Visual accuracy (same block)")
plt.xlabel('round number')
plt.ylabel('accuracy')
# Out:
# Text(0, 0.5, 'accuracy')
